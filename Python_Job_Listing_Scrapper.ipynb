# %%
first_job = job_elements[0]

print(first_job)
# Out:
# <div class="card-content">
# <div class="media">
# <div class="media-left">
# <figure class="image is-48x48">
# <img alt="Real Python Logo" src="https://files.realpython.com/media/real-python-logo-thumbnail.7f0db70c2ed2.jpg?__no_cf_polish=1"/>
# </figure>
# </div>
# <div class="media-content">
# <h2 class="title is-5">Senior Python Developer</h2>
# <h3 class="subtitle is-6 company">Payne, Roberts and Davis</h3>
# </div>
# </div>
# <div class="content">
# <p class="location">
#         Stewartbury, AA
#       </p>
# <p class="is-small has-text-grey">
# <time datetime="2021-04-08">2021-04-08</time>
# </p>
# </div>
# <footer class="card-footer">
# <a class="card-footer-item" href="https://www.realpython.com" target="_blank">Learn</a>
# <a class="card-footer-item" href="https://realpython.github.io/fake-jobs/jobs/senior-python-developer-0.html" target="_blank">Apply</a>
# </footer>
# </div>

# %%
title_element = first_job.find("h2", class_="title")
title = title_element.text.strip()

company_element = first_job.find("h3", class_="company")
company = company_element.text.strip()

location_element = first_job.find("p", class_="location")
location = location_element.text.strip()

print(title)
print(company)
print(location)
# Out:
# Senior Python Developer
# Payne, Roberts and Davis
# Stewartbury, AA

# %%
all_links = first_job.find_all("a")
apply_link = all_links[1]
url = apply_link["href"]

print(url)
# Out:
# https://realpython.github.io/fake-jobs/jobs/senior-python-developer-0.html

# %%
job_cards = soup.find_all("div", class_="card-content")
for card in job_cards:

    title_element = card.find("h2", class_="title")
    title = title_element.text.strip()

    company_element = card.find("h3", class_="company")
    company = company_element.text.strip()

    location_element = card.find("p", class_="location")
    location = location_element.text.strip()

    links = card.find_all("a")
    apply_url = links[1]["href"]

    print(f"Job: {title}")
    print(f"Company: {company}")
    print(f"Location: {location}")
    print(f"Apply: {apply_url}")
    print("-" * 30) # Separator line
# Out:
# Job: Senior Python Developer
# Company: Payne, Roberts and Davis
# Location: Stewartbury, AA
# Apply: https://realpython.github.io/fake-jobs/jobs/senior-python-developer-0.html
# ------------------------------
# Job: Energy engineer
# Company: Vasquez-Davidson
# Location: Christopherville, AA
# Apply: https://realpython.github.io/fake-jobs/jobs/energy-engineer-1.html
# ------------------------------
# Job: Legal executive
# Company: Jackson, Chambers and Levy
# Location: Port Ericaburgh, AA
# Apply: https://realpython.github.io/fake-jobs/jobs/legal-executive-2.html
# ------------------------------
# Job: Fitness centre manager
# Company: Savage-Bradley
# Location: East Seanview, AP
# Apply: https://realpython.github.io/fake-jobs/jobs/fitness-centre-manager-3.html
# ------------------------------
# Job: Product manager
# Company: Ramirez Inc
# Location: North Jamieview, AP
# Apply: https://realpython.github.io/fake-jobs/jobs/product-manager-4.html
# ------------------------------
# Job: Medical technical officer
# Company: Rogers-Yates
# Location: Davidville, AP
# Apply: https://realpython.github.io/fake-jobs/jobs/medical-technical-officer-5.html
# ------------------------------
# Job: Physiological scientist
# Company: Kramer-Klein
# Location: South Christopher, AE
# Apply: https://realpython.github.io/fake-jobs/jobs/physiological-scientist-6.html
# ------------------------------
# Job: Textile designer
# Company: Meyers-Johnson
# Location: Port Jonathan, AE
# Apply: https://realpython.github.io/fake-jobs/jobs/textile-designer-7.html
# ------------------------------
# Job: Television floor manager
# Company: Hughes-Williams
# Location: Osbornetown, AE
# Apply: https://realpython.github.io/fake-jobs/jobs/television-floor-manager-8.html
# ------------------------------
# Job: Waste management officer
# Company: Jones, Williams and Villa
# Location: Scotttown, AP
# Apply: https://realpython.github.io/fake-jobs/jobs/waste-management-officer-9.html
# ------------------------------
# Job: Software Engineer (Python)
# Company: Garcia PLC
# Location: Ericberg, AE
# Apply: https://realpython.github.io/fake-jobs/jobs/software-engineer-python-10.html
# ------------------------------
# Job: Interpreter
# Company: Gregory and Sons
# Location: Ramireztown, AE
# Apply: https://realpython.github.io/fake-jobs/jobs/interpreter-11.html
# ------------------------------
# Job: Architect
# Company: Clark, Garcia and Sosa
# Location: Figueroaview, AA
# Apply: https://realpython.github.io/fake-jobs/jobs/architect-12.html
# ------------------------------
# Job: Meteorologist
# Company: Bush PLC
# Location: Kelseystad, AA
# Apply: https://realpython.github.io/fake-jobs/jobs/meteorologist-13.html
# ------------------------------
# Job: Audiological scientist
# Company: Salazar-Meyers
# Location: Williamsburgh, AE
# Apply: https://realpython.github.io/fake-jobs/jobs/audiological-scientist-14.html
# ------------------------------
# Job: English as a second language teacher
# Company: Parker, Murphy and Brooks
# Location: Mitchellburgh, AE
# Apply: https://realpython.github.io/fake-jobs/jobs/english-as-a-second-language-teacher-15.html
# ------------------------------
# Job: Surgeon
# Company: Cruz-Brown
# Location: West Jessicabury, AA
# Apply: https://realpython.github.io/fake-jobs/jobs
AE
# Apply: https://realpython.github.io/fake-jobs/jobs/surveyor-land-geomatics-91.html
# ------------------------------
# Job: Legal executive
# Company: Hartman PLC
# Location: West Ericstad, AA
# Apply: https://realpython.github.io/fake-jobs/jobs/legal-executive-92.html
# ------------------------------
# Job: Librarian, academic
# Company: Brooks Inc
# Location: Tuckertown, AE
# Apply: https://realpython.github.io/fake-jobs/jobs/librarian-academic-93.html
# ------------------------------
# Job: Barrister
# Company: Washington-Castillo
# Location: Perezton, AE
# Apply: https://realpython.github.io/fake-jobs/jobs/barrister-94.html
# ------------------------------
# Job: Museum/gallery exhibitions officer
# Company: Nguyen, Yoder and Petty
# Location: Lake Abigail, AE
# Apply: https://realpython.github.io/fake-jobs/jobs/museum-gallery-exhibitions-officer-95.html
# ------------------------------
# Job: Radiographer, diagnostic
# Company: Holder LLC
# Location: Jacobshire, AP
# Apply: https://realpython.github.io/fake-jobs/jobs/radiographer-diagnostic-96.html
# ------------------------------
# Job: Database administrator
# Company: Yates-Ferguson
# Location: Port Susan, AE
# Apply: https://realpython.github.io/fake-jobs/jobs/database-administrator-97.html
# ------------------------------
# Job: Furniture designer
# Company: Ortega-Lawrence
# Location: North Tiffany, AA
# Apply: https://realpython.github.io/fake-jobs/jobs/furniture-designer-98.html
# ------------------------------
# Job: Ship broker
# Company: Fuentes, Walls and Castro
# Location: Michelleville, AP
# Apply: https://realpython.github.io/fake-jobs/jobs/ship-broker-99.html
# ------------------------------

# %%
import requests
from bs4 import BeautifulSoup
import csv

# --- CONFIGURATION ---
URL = "https://realpython.github.io/fake-jobs/"
OUTPUT_FILE = 'job_results.csv'

def scrape_jobs():
    """
    Scrapes job listings from the fake-jobs website and saves them to a CSV file.
    """
    print("Connecting to website...")
    # 1. Get the page content
    page = requests.get(URL)

    # Check if connection was successful
    if page.status_code != 200:
        print(f"Failed to load page. Status code: {page.status_code}")
        return

    # 2. Parse HTML content
    soup = BeautifulSoup(page.content, "html.parser")

    # 3. Find all job cards
    job_cards = soup.find_all("div", class_="card-content")
    print(f"Found {len(job_cards)} job listings. Starting extraction...")

    # 4. Prepare CSV file
    try:
        with open(OUTPUT_FILE, mode='w', newline='', encoding='utf-8') as file:
            writer = csv.writer(file)

            # Write Header
            writer.writerow(['Job Title', 'Company', 'Location', 'Apply Link'])

            # 5. Loop through each card
            for card in job_cards:

                # --- EXTRACT DATA & HANDLE EDGE CASES ---

                # Job Title
                title_elem = card.find("h2", class_="title")
                title = title_elem.text.strip() if title_elem else "Title Missing"

                # Company Name
                company_elem = card.find("h3", class_="company")
                company = company_elem.text.strip() if company_elem else "Company Missing"

                # Location
                location_elem = card.find("p", class_="location")
                location = location_elem.text.strip() if location_elem else "Location Missing"

                # Apply Link
                links = card.find_all("a")
                if len(links) >= 2:
                    apply_url = links[1]["href"]
                else:
                    apply_url = "Link Missing"

                # --- SAVE ROW ---
                writer.writerow([title, company, location, apply_url])

        print(f"Success! Data saved to '{OUTPUT_FILE}'")

    except Exception as e:
        print(f"An error occurred while writing the file: {e}")

# --- MAIN EXECUTION ---
if __name__ == "__main__":
    scrape_jobs()
# Out:
# Connecting to website...
# Found 100 job listings. Starting extraction...
# Success! Data saved to 'job_results.csv'
